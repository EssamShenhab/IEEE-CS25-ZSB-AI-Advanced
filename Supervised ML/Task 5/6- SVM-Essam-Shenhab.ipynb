# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np

# %%
# Read the data.
data = np.asarray(pd.read_csv('data.csv', header=None))
# TODO: Assign the features to the variable X, and the labels to the variable y. 
X = data[:, :-1]
y = data[:, -1]

# %%
import matplotlib.pyplot as plt

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %%
# TODO: Create the model and assign it to the variable model.
# Find the right parameters for this model to achieve 100% accuracy on the dataset.
model1 = SVC(C=1.0, kernel='rbf', gamma='scale', random_state=42)

# TODO: Fit the model.
model1.fit(X, y)

# TODO: Make predictions. Store them in the variable y_pred.
y_pred = model1.predict(X)

# TODO: Calculate the accuracy and assign it to the variable acc.
train_acc = accuracy_score(y, y_pred)
train_acc
# Out:
# 0.8541666666666666

# %%
# Plot decision boundaries
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 300),
                     np.linspace(y_min, y_max, 300))

Z = model1.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.coolwarm)
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolor="k", cmap=plt.cm.coolwarm)
plt.title(f"SVC decision boundaries (acc={train_acc:.2f})")


plt.show()

# %%
model2 = SVC(C=100.0, kernel='rbf', gamma='scale', random_state=42)

# TODO: Fit the model.
model2.fit(X, y)

# TODO: Make predictions. Store them in the variable y_pred.
y_pred = model2.predict(X)

# TODO: Calculate the accuracy and assign it to the variable acc.
pred_acc = accuracy_score(y, y_pred)
pred_acc
# Out:
# 1.0

# %%
# Plot decision boundaries
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 300),
                     np.linspace(y_min, y_max, 300))

Z = model2.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.coolwarm)
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolor="k", cmap=plt.cm.coolwarm)
plt.title(f"SVC decision boundaries (acc={pred_acc:.2f})")


plt.show()
